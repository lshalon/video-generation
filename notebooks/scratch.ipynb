# %% [markdown]
# # Scratch Notebook
#
# Exploratory notebook for video generation experiments.

# %%
from video_generation import (
    __version__,
    # Media utilities
    display_image,
    display_video,
    save_image,
    save_video,
    # Prompt utilities
    load_prompt,
    list_prompts,
    save_prompt,
    # Config
    load_env,
    get_api_key,
)

print(f"video-generation v{__version__}")

# %% [markdown]
# ## Prompt Management
#
# Prompts are stored as text files in `data/prompts/`. You can organize them by category.

# %%
# List all available prompts
list_prompts()

# %%
# Load an example prompt
prompt = load_prompt("image_generation", category="examples")
print(prompt)

# %%
# Save a new prompt
# save_prompt("my_prompt", "Your prompt text here", category="examples")

# %% [markdown]
# ## API Configuration
#
# Copy `.env.example` to `.env` and add your API keys.

# %%
# Load environment variables from .env
load_env()

# Check which API keys are configured
from video_generation.clients.config import check_api_keys
check_api_keys()

# %%
# Example: Get API clients (uncomment when keys are set)
# from video_generation.clients import get_openai_client, get_anthropic_client
# openai_client = get_openai_client()
# anthropic_client = get_anthropic_client()

# %% [markdown]
# ## Media Display & Storage
#
# Use `display_image()` and `display_video()` to render media in notebooks.
# Use `save_image()` and `save_video()` to save with consistent naming.

# %%
# Example: Display an image from URL
# display_image("https://example.com/image.png", width=400)

# Example: Display a local video
# display_video("data/outputs/videos/my_video.mp4")

# Example: Save generated content
# path = save_image(image_bytes, prefix="dalle")
# print(f"Saved to: {path}")
